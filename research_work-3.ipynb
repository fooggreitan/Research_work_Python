# %%
import pandas as pd

df = pd.read_csv('D:/california_housing_test.csv')

print(df)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.isnull()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df[df['median_income'] < 2]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5       -119.56     36.51                37.0       1018.0           213.0
# 6       -121.43     38.63                43.0       1009.0           225.0
# 16      -120.81     37.53                15.0        570.0           123.0
# 28      -118.45     34.07                19.0       4845.0          1609.0
# 43      -117.27     34.09                36.0        848.0           186.0
# ...         ...       ...                 ...          ...             ...
# 2943    -121.23     37.96                37.0       2351.0           564.0
# 2964    -118.25     33.94                43.0       1113.0           378.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2986    -118.25     33.93                42.0        819.0           233.0
# 2995    -119.86     34.42                23.0       1450.0           642.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[df['median_income'] < 2]['latitude']
# Out:
# 5       36.51
# 6       38.63
# 16      37.53
# 28      34.07
# 43      34.09
#         ...
# 2943    37.96
# 2964    33.94
# 2985    34.94
# 2986    33.93
# 2995    34.42
# Name: latitude, Length: 360, dtype: float64

# %%
df.loc[df['median_income'] < 2, 'median_house_value'] # или df[df['median_income'] < 2]['median_house_value']
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df[df['median_income'] < 2]['median_house_value']
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df[df['median_income'] < 2][['longitude','latitude']]
# Out:
#       longitude  latitude
# 5       -119.56     36.51
# 6       -121.43     38.63
# 16      -120.81     37.53
# 28      -118.45     34.07
# 43      -117.27     34.09
# ...         ...       ...
# 2943    -121.23     37.96
# 2964    -118.25     33.94
# 2985    -120.47     34.94
# 2986    -118.25     33.93
# 2995    -119.86     34.42
#
# [360 rows x 2 columns]

# %%
df[(df['housing_median_age'] < 20) & (df['median_house_value']> 70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %%
print(df['median_house_value'].max())
# Out:
# 500001.0

# %%
print(df['median_house_value'].min())
# Out:
# 22500.0

# %%
df[df['median_income']==3.1250]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 207     -122.10     37.68                31.0       1892.0           428.0
# 784     -118.31     33.80                30.0       3096.0           757.0
# 904     -120.77     37.01                28.0       1689.0           378.0
# 1908    -119.19     34.22                26.0       3175.0           736.0
#
#       population  households  median_income  median_house_value
# 207       1162.0       389.0          3.125            167100.0
# 784       2048.0       704.0          3.125            233300.0
# 904       1057.0       267.0          3.125            156300.0
# 1908      2460.0       775.0          3.125            219900.0

# %%
print(df[df['median_income']==3.1250]['median_house_value'].max())
# Out:
# 233300.0

# %%
print(df['median_house_value'].max())
# Out:
# 500001.0

# %%
df[df['median_house_value']==500001.0]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 42      -118.06     34.15                37.0       1980.0           226.0
# 117     -122.07     37.34                30.0       1851.0           238.0
# 118     -117.18     33.02                15.0       3540.0           453.0
# 128     -122.47     37.79                52.0       2844.0           623.0
# 135     -122.34     37.56                39.0       3562.0           391.0
# ...         ...       ...                 ...          ...             ...
# 2960    -117.89     33.60                36.0       1496.0           247.0
# 2968    -119.23     34.17                18.0       6171.0          1490.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2993    -117.91     33.60                37.0       2088.0           510.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
print(df[df['median_house_value']==500001.0]['population'].max())
# Out:
# 7431.0
